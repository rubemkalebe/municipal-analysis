# %% [markdown]
# ## Municipal Analyis of Natal

# %% [markdown]
# ###### An analysis of Municipal Schools and Health Units in Natal, Brazil
#
# The data were collected in http://ckan.imd.ufrn.br/

# %% [markdown]
# ### Health Units

# %% [markdown]
# In this section we look at the amount of practitioners who work in the health units and how the units are distributed on the city.

# %%
from src.data.get_health_units import GetHealthUnits

# Data collection of health units
health_units = GetHealthUnits.get()

# %% [markdown]
# #### Geographic visualization

# %%
from src.visualization.map.health_units_map import HealthUnitsMap

# Generates a map showing the localization of each unit
hu_map = HealthUnitsMap(health_units)
hu_map.generateMap()
# Out:
# 100%|██████████| 39/39 [00:02<00:00, 18.58it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from src.visualization.heatmap.health_units_heatmap import HealthUnitsHeatmap

# Generates a heat map of each unit by its amount of employees
hu_heatmap = HealthUnitsHeatmap(health_units)
hu_heatmap.generateMap()
# Out:
# 100%|██████████| 39/39 [00:00<00:00, 109636.63it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Charts

# %%
from bokeh.io import output_notebook, show

# %%
from src.visualization.charts.employees_by_region import EmployeesByRegion

employeesByReg = EmployeesByRegion(health_units)
practitionersByRegions = employeesByReg.plot('Practitioners by sanitary districts')

output_notebook()
show(practitionersByRegions)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ca222d79-65fe-466d-a555-6cda916fcba7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f5c97305-b40d-4060-8f0f-5c64735fc3aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f5c97305-b40d-4060-8f0f-5c64735fc3aa").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5c97305-b40d-4060-8f0f-5c64735fc3aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5c97305-b40d-4060-8f0f-5c64735fc3aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cbfca4cc-820c-4f55-afd2-6f99895fc1d0":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":317,"regions":"NORTE I"}],"color":["#407ee7"],"employees":[317],"fill_alpha":[0.8],"height":[317.0],"label":[{"employees":317,"regions":"NORTE I"}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE I"],"width":[0.8],"x":["NORTE I"],"y":[158.5]}},"id":"d29e4cec-1575-4337-9473-227f44fd077a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e08a2c32-d5a8-400d-8fea-6a31a2d08615","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"723cc668-59b0-4d00-b51d-c548a8f283a7","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c417fed7-c7a8-4308-858c-eef8ef927795","type":"Rect"},{"attributes":{"data_source":{"id":"d29e4cec-1575-4337-9473-227f44fd077a","type":"ColumnDataSource"},"glyph":{"id":"e08a2c32-d5a8-400d-8fea-6a31a2d08615","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a5f76edd-55de-4b21-b865-6681c3f4cfb7","type":"GlyphRenderer"},{"attributes":{},"id":"387c4ae0-8a01-4599-95f7-05c4a9002229","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":333,"regions":"NORTE II"}],"color":["#df5320"],"employees":[333],"fill_alpha":[0.8],"height":[333.0],"label":[{"employees":333,"regions":"NORTE II"}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE II"],"width":[0.8],"x":["NORTE II"],"y":[166.5]}},"id":"51771744-0a73-445c-83f5-7a290503b219","type":"ColumnDataSource"},{"attributes":{},"id":"38a83141-497d-4ca8-a52a-61965cea7944","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":52,"regions":"SUL"}],"color":["#f22c40"],"employees":[52],"fill_alpha":[0.8],"height":[52.0],"label":[{"employees":52,"regions":"SUL"}],"line_alpha":[1.0],"line_color":["white"],"regions":["SUL"],"width":[0.8],"x":["SUL"],"y":[26.0]}},"id":"76d9dd33-88b8-476a-8bae-56c49bbd46a7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"51771744-0a73-445c-83f5-7a290503b219","type":"ColumnDataSource"},"glyph":{"id":"c417fed7-c7a8-4308-858c-eef8ef927795","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"026d0acb-a393-4956-8948-ce29cac6a69f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ed41c0a6-4d49-4f3b-a109-508276e292c9","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":142,"regions":"LESTE"}],"color":["#5ab738"],"employees":[142],"fill_alpha":[0.8],"height":[142.0],"label":[{"employees":142,"regions":"LESTE"}],"line_alpha":[1.0],"line_color":["white"],"regions":["LESTE"],"width":[0.8],"x":["LESTE"],"y":[71.0]}},"id":"800f4695-56e4-48d3-b35e-6b85ad4979fb","type":"ColumnDataSour ...

# %%
from src.visualization.charts.places_by_region import PlacesByRegion

placesByReg = PlacesByRegion(health_units)
unitsByReg = placesByReg.plot('Health units by region')

output_notebook()
show(unitsByReg)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="357ca32a-c63b-4d93-9e1f-25a95eccb085">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c8ac6b9c-051a-481c-ac5f-1444b9f9e075"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c8ac6b9c-051a-481c-ac5f-1444b9f9e075").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c8ac6b9c-051a-481c-ac5f-1444b9f9e075");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c8ac6b9c-051a-481c-ac5f-1444b9f9e075' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a193ace1-dbe7-42cb-b2c5-712106f73051":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d718af31-92f1-49af-bca3-703a0fd2fb19","type":"Rect"},{"attributes":{"data_source":{"id":"a001bcb9-11d3-43f5-9d0d-75cbdf6c0b38","type":"ColumnDataSource"},"glyph":{"id":"264c4cf2-6f72-4eca-9ed1-47f68cd799e0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3f2c0736-82a2-4fef-b33a-b6e6122eefdb","type":"GlyphRenderer"},{"attributes":{},"id":"66059cff-2a90-433c-9bc3-393b25a8b783","type":"ToolEvents"},{"attributes":{"below":[{"id":"f810ed84-6be5-4b29-ad62-11878137e418","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"524d592a-a9f1-48a0-887a-697b8e54fd07","type":"LinearAxis"}],"renderers":[{"id":"2cfb2013-57a4-4bd4-ad03-3b94309b049a","type":"BoxAnnotation"},{"id":"6a83a5e8-e1a5-4a97-beac-d8d6d6038d96","type":"GlyphRenderer"},{"id":"3f2c0736-82a2-4fef-b33a-b6e6122eefdb","type":"GlyphRenderer"},{"id":"278ca658-2f61-41c2-8081-6f6e5eac0667","type":"GlyphRenderer"},{"id":"9813f0fc-095e-47de-a088-3c885ed23c77","type":"GlyphRenderer"},{"id":"f32b9d29-22e3-4e55-bdbe-9a3ec28c2bb7","type":"GlyphRenderer"},{"id":"f810ed84-6be5-4b29-ad62-11878137e418","type":"CategoricalAxis"},{"id":"524d592a-a9f1-48a0-887a-697b8e54fd07","type":"LinearAxis"},{"id":"e164a842-ec58-483a-8488-c5b391a2f536","type":"Grid"}],"title":{"id":"b55f7d2e-7a0f-4694-b979-7c397f2a42bc","type":"Title"},"tool_events":{"id":"66059cff-2a90-433c-9bc3-393b25a8b783","type":"ToolEvents"},"toolbar":{"id":"adb25c1d-62a6-44e6-8c40-af8f4ffd18ec","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"7ac42224-99f9-4a4c-8483-3d7a29e1f08f","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"0834b9df-58cb-4080-a399-4417d98b24d4","type":"Range1d"}},"id":"5a7ef697-bff8-408d-960c-864a7a61c18f","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"a01743de-5849-4dcb-83c0-36a877c984e2","type":"ColumnDataSource"},"glyph":{"id":"be21b2fd-112f-4cc3-99d5-92b9fc353e40","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"278ca658-2f61-41c2-8081-6f6e5eac0667","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"NORTE I","units":11}],"color":["#df5320"],"fill_alpha":[0.8],"height":[11.0],"label":[{"regions":"NORTE I","units":11}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE I"],"units":[11],"width":[0.8],"x":["NORTE I"],"y":[5.5]}},"id":"a001bcb9-11d3-43f5-9d0d-75cbdf6c0b38","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"264c4cf2-6f72-4eca-9ed1-47f68cd799e0","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"be21b2fd-112f-4cc3-99d5-92b9fc353e40","type":"Rect"},{"attributes":{"data_source":{"id":"d043a4d0-e2f4-463f-9a1c-d234394397cf","type":"ColumnDataSource"},"glyph":{"id":"3daf6823-005e-4f1d-8d04-4e5a9a4e54aa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6a83a5e8-e1a5-4a97-beac-d8d6d6038d96","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"NORTE II","units":10}],"color":["#407ee7"],"fill_alpha":[0.8],"heig ...

# %% [markdown]
# ### Municipal Schools

# %% [markdown]
# In this section we look at the amount of teachers who work in the municipal schools and how those schools are distributed on the city.

# %%
from src.data.get_mun_schools import GetMunicipalSchools

# Data collection of municipal schools
schools = GetMunicipalSchools.get()

# %% [markdown]
# #### Geographic visualization

# %%
from src.visualization.map.mun_schools_map import MunicipalSchoolsMap

# Generates a map showing the localization of each unit
ms_map = MunicipalSchoolsMap(schools)
ms_map.generateMap()
# Out:
# 100%|██████████| 146/146 [00:07<00:00, 18.82it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from src.visualization.heatmap.mun_schools_heatmap import MunicipalSchoolsHeatmap

# Generates a heat map of each school by its amount of teachers
ms_heatmap = MunicipalSchoolsHeatmap(schools)
ms_heatmap.generateMap()
# Out:
# 100%|██████████| 146/146 [00:00<00:00, 148560.99it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Charts

# %%
from bokeh.io import output_notebook, show

# %%
from src.visualization.charts.employees_by_region import EmployeesByRegion

employeesByReg = EmployeesByRegion(schools)
teachersByRegions = employeesByReg.plot('Teachers by local region')

output_notebook()
show(teachersByRegions)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7307a657-cc6e-4fbc-8d01-5ec443c00f1e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="673da1dc-323d-484b-b8db-58c5ab426c4f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("673da1dc-323d-484b-b8db-58c5ab426c4f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("673da1dc-323d-484b-b8db-58c5ab426c4f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '673da1dc-323d-484b-b8db-58c5ab426c4f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d906aee3-1755-43ba-a773-9b6508af25e8":{"roots":{"references":[{"attributes":{"plot":{"id":"a12ee42a-7866-46d4-b023-6d4213fe82aa","subtype":"Chart","type":"Plot"}},"id":"84d6a003-9e3e-46f8-ba31-6bf7adaa913c","type":"SaveTool"},{"attributes":{"below":[{"id":"1e7b983e-1ac8-4b27-b546-6105d6f9382f","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"d5ec154b-81ed-4fb1-9dee-9c5c9bb3a508","type":"LinearAxis"}],"renderers":[{"id":"ccfde028-58b5-4cd0-972d-77730a147d14","type":"BoxAnnotation"},{"id":"6552121e-d957-4317-b2d9-82c6139f25f7","type":"GlyphRenderer"},{"id":"460b9c1f-ce4a-45bc-9d35-5f18903bddae","type":"GlyphRenderer"},{"id":"fdd925d4-3b50-45a2-9bd8-9156a0800974","type":"GlyphRenderer"},{"id":"7ea3dddc-3387-4e01-96b1-1d41d49e38e6","type":"GlyphRenderer"},{"id":"dbe49d53-08fb-434f-b66c-fffb10e1941b","type":"GlyphRenderer"},{"id":"1e7b983e-1ac8-4b27-b546-6105d6f9382f","type":"CategoricalAxis"},{"id":"d5ec154b-81ed-4fb1-9dee-9c5c9bb3a508","type":"LinearAxis"},{"id":"a2b0d0cb-125b-4c82-8f31-65c7955c289f","type":"Grid"}],"title":{"id":"55bacca3-0773-4b9e-b685-10fb6bba981f","type":"Title"},"tool_events":{"id":"20c49c6c-c39a-4958-bc4c-267428af5725","type":"ToolEvents"},"toolbar":{"id":"9d094ae4-10e2-479f-8430-dd28640adc3c","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"d27c292f-fa4f-43f0-ad89-ddd6b951e9bf","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"72e7c42d-ef2f-4972-ba58-3474d9068a0c","type":"Range1d"}},"id":"a12ee42a-7866-46d4-b023-6d4213fe82aa","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"e8cb8b19-9bf5-4264-a28e-5f2a6fd5a9e6","type":"BasicTicker"},{"attributes":{},"id":"a4f3283e-d0fd-4171-a75b-b1b89df43900","type":"CategoricalTickFormatter"},{"attributes":{},"id":"edd4bade-ba34-46bb-a353-f1cfd7333888","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"78ec483e-6bed-45ab-a1ef-bb0cf4146b21","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ccfde028-58b5-4cd0-972d-77730a147d14","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"e88f5856-6632-4659-9433-28bcce3adb45","type":"ColumnDataSource"},"glyph":{"id":"78ec483e-6bed-45ab-a1ef-bb0cf4146b21","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"dbe49d53-08fb-434f-b66c-fffb10e1941b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":767,"regions":"SUL"}],"color":["#407ee7"],"employees":[767],"fill_alpha":[0.8],"height":[767.0],"label":[{"employees":767,"regions":"SUL"}],"line_alpha":[1.0],"line_color":["white"],"regions":["SUL"],"width":[0.8],"x":["SUL"],"y":[383.5]}},"id":"e88f5856-6632-4659-9433-28bcce3adb45","type":"ColumnDataSource"},{"attributes":{"axis_label":"Regions","formatter":{"id":"a4f3283e-d0fd-4171-a75b-b1b89df43900","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"a12ee42a-7866-46d4-b023-6d4213fe82aa","subtype":"Chart","type":"Plot"},"ticker":{"id":"edd4bade-ba34-46bb-a353-f1cfd7333888","type":"CategoricalTicker"}},"id":"1e7b983e-1ac8-4b27-b546-6105d6f9382f","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"a12ee42a-7866-46d4-b023-6d4213fe82aa","subtype":"Chart","type":"Plot"}},"id":"8ae91bdf-80b6-4320-9f79-42440b2f32c1","type":"PanTool"},{"attributes":{"callback":null,"end":2484.3},"id":"72e7c42d-ef2f-4972-ba58-3474d9068a0c","type":"Range1d"},{"attributes":{" ...

# %%
from src.visualization.charts.places_by_region import PlacesByRegion

placesByReg = PlacesByRegion(schools)
schoolsByReg = placesByReg.plot('Schools by region')

output_notebook()
show(schoolsByReg)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="75f62dcf-bffb-4aa8-a655-5f1f0761db80">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="78fb0a31-76dd-41f8-9123-fd5a9bfd117c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("78fb0a31-76dd-41f8-9123-fd5a9bfd117c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("78fb0a31-76dd-41f8-9123-fd5a9bfd117c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '78fb0a31-76dd-41f8-9123-fd5a9bfd117c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d98c7f8d-0a6f-43af-95cc-a1e30b328408":{"roots":{"references":[{"attributes":{},"id":"f569e4f8-3f3e-437e-9e84-384331784fa5","type":"CategoricalTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"e36ac280-0dd7-4265-b8df-e7f6e41db7b1","subtype":"Chart","type":"Plot"},"ticker":{"id":"ae9a6c65-3e2c-405a-bb97-ddbb3e2a5418","type":"BasicTicker"}},"id":"6c91cfab-9be1-4455-ad3d-b3e7c509c9de","type":"Grid"},{"attributes":{},"id":"97483da9-b44e-401e-8d14-7d07ce2ab436","type":"ToolEvents"},{"attributes":{},"id":"a24e0f45-e628-49d7-88fe-6f84e682f8cb","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"e36ac280-0dd7-4265-b8df-e7f6e41db7b1","subtype":"Chart","type":"Plot"}},"id":"484182e4-a400-4a02-9b7f-dbf089ba4e19","type":"HelpTool"},{"attributes":{"plot":{"id":"e36ac280-0dd7-4265-b8df-e7f6e41db7b1","subtype":"Chart","type":"Plot"}},"id":"b81f59b7-1482-41c2-b76d-8ea360151402","type":"PanTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"67117e04-bb18-49b6-94eb-1a4561187816","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"LESTE","units":17}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[17.0],"label":[{"regions":"LESTE","units":17}],"line_alpha":[1.0],"line_color":["white"],"regions":["LESTE"],"units":[17],"width":[0.8],"x":["LESTE"],"y":[8.5]}},"id":"9a2805f6-ed5f-4fc8-a00b-acfb58425a78","type":"ColumnDataSource"},{"attributes":{},"id":"2c9e7894-dfbb-428f-a325-906285688c87","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8e914ebf-c31a-471d-a7ae-3c53784ec730","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"fc55354f-5fa3-4a15-a0ad-ed436ee26e53","type":"ColumnDataSource"},"glyph":{"id":"53443d46-0dbc-495c-8337-959212a62e55","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"992db7a0-c25c-46ae-81a4-215abdb63a0c","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5108e18b-9f58-4fe4-a071-9b823bbe49df","type":"Rect"},{"attributes":{"callback":null,"factors":["LESTE","NORTE","N\u00c3O DEFINIDO","OESTE","SUL"]},"id":"507b9256-2bd9-4f8e-82b4-b0e4fe2663ef","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"NORTE","units":55}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[55.0],"label":[{"regions":"NORTE","units":55}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE"],"units":[55],"width":[0.8],"x":["NORTE"],"y":[27.5]}},"id":"7350ef0b-ecfc-43f0-8e10-804fdfc04851","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"9a2805f6-ed5f-4fc8-a00b-acfb58425a78","type":"ColumnDataSource"},"glyph":{"id":"67117e04-bb18-49b6-94eb-1a4561187816","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0fcdf181-2a0b-499b-bf77-5fe6e702dde4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"N\u00c3O DEFINIDO","units":13}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[13.0],"label":[{"regions":"N\u00c3O DEFINIDO ...

# %%
from src.visualization.charts.teachers_education import TeachersEducationPlot

# Chart summarizing teachers education
teacEduc = TeachersEducationPlot(schools)
teacEducPlot = teacEduc.plot()

output_notebook()
show(teacEducPlot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1d3b68d6-0985-4ab7-8285-aac96abafb72">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="abcf0b27-acfb-45f0-aea8-e6cf698468e4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("abcf0b27-acfb-45f0-aea8-e6cf698468e4").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("abcf0b27-acfb-45f0-aea8-e6cf698468e4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'abcf0b27-acfb-45f0-aea8-e6cf698468e4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"25d9f44c-e836-4d7e-889a-c8965e21569d":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"77902092-3c8b-4650-af95-d6bdabd6cfc6","type":"PanTool"},{"id":"1d47ab79-3ddd-4e73-95a0-7b0676a32523","type":"WheelZoomTool"},{"id":"342a6d52-819e-4c93-909f-4bf8908fd566","type":"BoxZoomTool"},{"id":"454c0553-70b5-43e2-b038-a1871ecae509","type":"SaveTool"},{"id":"82c464fe-6fc6-43d7-839b-308403710395","type":"ResetTool"},{"id":"c27dfbbb-b0ca-4b17-8ecb-44d7a8bc94f0","type":"HelpTool"}]},"id":"4b61db6a-5feb-49b4-87a9-843b8f0eb181","type":"Toolbar"},{"attributes":{"plot":null,"text":null},"id":"f9da18e0-e7d3-47be-bf14-404d74895245","type":"Title"},{"attributes":{},"id":"7358d55d-298a-4e96-a98d-cd2d365e7eb5","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"29327f8f-9746-4c62-be34-b25c0f6b782c","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"7c7034c5-e028-4a95-99d4-a129891a1baa","subtype":"Chart","type":"Plot"}},"id":"77902092-3c8b-4650-af95-d6bdabd6cfc6","type":"PanTool"},{"attributes":{"axis_label":null,"formatter":{"id":"7358d55d-298a-4e96-a98d-cd2d365e7eb5","type":"BasicTickFormatter"},"plot":{"id":"7c7034c5-e028-4a95-99d4-a129891a1baa","subtype":"Chart","type":"Plot"},"ticker":{"id":"395105a7-958b-4124-a9d7-8d7b7189d4b7","type":"BasicTicker"},"visible":false},"id":"1b91a52a-a8bb-4374-b869-503f5d2180af","type":"LinearAxis"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"e7b65bd5-bd97-409a-afa4-d8fc0c239ff2","type":"AnnularWedge"},{"attributes":{"plot":{"id":"7c7034c5-e028-4a95-99d4-a129891a1baa","subtype":"Chart","type":"Plot"}},"id":"1d47ab79-3ddd-4e73-95a0-7b0676a32523","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"29327f8f-9746-4c62-be34-b25c0f6b782c","type":"BoxAnnotation"},"plot":{"id":"7c7034c5-e028-4a95-99d4-a129891a1baa","subtype":"Chart","type":"Plot"}},"id":"342a6d52-819e-4c93-909f-4bf8908fd566","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"7c7034c5-e028-4a95-99d4-a129891a1baa","subtype":"Chart","type":"Plot"}},"id":"454c0553-70b5-43e2-b038-a1871ecae509","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","education"],"data":{"centers":[1.125,1.125,1.125,1.125],"color":["#f22c40","#5ab738","#407ee7","#df5320"],"education":["Ensino Superior","Especializa\u00e7\u00e3o","Mestrado","Nenhum"],"end":[3.141592653589793,4.383617656171804,4.529738244710864,6.283185307179586],"inners":[0.0,0.0,0.0,0.0],"level":[0.0,0.0,0.0,0.0],"outers":[1.5,1.5,1.5,1.5],"start":[0.0,3.141592653589793,4.383617656171804,4.529738244710864],"values":[6278,2482,292,3504]}},"id":"70c6c886-0bcc-4b03-96a6-068c737280b2","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"7c7034c5-e028-4a95-99d4-a129891a1baa","subtype":"Chart","type":"Plot"}},"id":"82c464fe-6fc6-43d7-839b-308403710395","type":"ResetTool"},{"attributes":{"plot":{"id":"7c7034c5-e028-4a95-99d4-a129891a1baa","subtype":"Chart","type":"Plot"}},"id":"c27dfbbb-b0ca-4b17-8ecb-44d7a8bc94f0","type":"HelpTool"},{"attributes":{"axis_label":null,"formatter":{"id":"95253e71-6806-43d4-ac94-45185e639184","type":"BasicTickFormatter"},"plot":{"id":"7c7034c5-e028-4a95-99d4-a129891a1baa","subtype":"Chart","type":"Plot"},"ticker":{"id":"a185c7a5-28b1-477c-b4ad-ee7fde5f59f2","type":"BasicTicker"},"visible":false},"id":"3cc77f39-74aa-456d-be2b-3cf906 ...

# %%
### REQUIREMENTS

### Libraries necessary to run this IPython Notebook

# !pip install folium
# !pip install geocoder
# !pip install tqdm

# %% [markdown]
# **Rubem Kalebe**
