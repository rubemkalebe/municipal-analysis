# %% [markdown]
# ## Municipal Analyis of Natal

# %% [markdown]
# ###### An analysis of Municipal Schools and Health Units in Natal, Brazil
#
# The data were collected in http://ckan.imd.ufrn.br/

# %% [markdown]
# ### Health Units

# %% [markdown]
# In this section we look at the amount of practitioners who work in the health units and how the units are distributed on the city.

# %%
from src.data.get_health_units import GetHealthUnits

# Data collection of health units
health_units = GetHealthUnits.get()

# %% [markdown]
# #### Geographic visualization

# %%
from src.visualization.map.health_units_map import HealthUnitsMap

# Generates a map showing the localization of each unit
hu_map = HealthUnitsMap(health_units)
hu_map.generateMap()
# Out:
# 100%|██████████| 39/39 [00:02<00:00, 15.76it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from src.visualization.heatmap.health_units_heatmap import HealthUnitsHeatmap

# Generates a heat map of each unit by its amount of employees
hu_heatmap = HealthUnitsHeatmap(health_units)
hu_heatmap.generateMap()
# Out:
# 100%|██████████| 39/39 [00:00<00:00, 94937.82it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Charts

# %%
from bokeh.io import output_notebook, show

# %%
from src.visualization.charts.employees_by_region import EmployeesByRegion

employeesByReg = EmployeesByRegion(health_units)
practitionersByRegions = employeesByReg.plot('Practitioners by sanitary districts')

output_notebook()
show(practitionersByRegions)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="927d14cf-3b15-4133-97d2-1bc881d99f72">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="46210994-8d55-42f3-9cf2-4b556eb784cf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("46210994-8d55-42f3-9cf2-4b556eb784cf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("46210994-8d55-42f3-9cf2-4b556eb784cf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '46210994-8d55-42f3-9cf2-4b556eb784cf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8f6ffd08-c57c-4a24-858b-1040972807d6":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":317,"regions":"NORTE I"}],"color":["#407ee7"],"employees":[317],"fill_alpha":[0.8],"height":[317.0],"label":[{"employees":317,"regions":"NORTE I"}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE I"],"width":[0.8],"x":["NORTE I"],"y":[158.5]}},"id":"bc3c9de8-f813-4c35-9b08-1cfb619bae28","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e8fd151c-280f-4493-b087-026901e4620f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4a1f6b53-004e-4be5-8f2b-567157ba3936","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"759531fd-76aa-4eee-a095-95b7709f2b1a","type":"Rect"},{"attributes":{"data_source":{"id":"bc3c9de8-f813-4c35-9b08-1cfb619bae28","type":"ColumnDataSource"},"glyph":{"id":"e8fd151c-280f-4493-b087-026901e4620f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"36d30e1e-84f3-4c02-84b2-aa590e52b64c","type":"GlyphRenderer"},{"attributes":{},"id":"e26e8fe1-40f4-45f1-83bf-242e27c17e8d","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":333,"regions":"NORTE II"}],"color":["#df5320"],"employees":[333],"fill_alpha":[0.8],"height":[333.0],"label":[{"employees":333,"regions":"NORTE II"}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE II"],"width":[0.8],"x":["NORTE II"],"y":[166.5]}},"id":"23e61362-8548-42b2-a118-6a472005cb59","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"23e61362-8548-42b2-a118-6a472005cb59","type":"ColumnDataSource"},"glyph":{"id":"759531fd-76aa-4eee-a095-95b7709f2b1a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"96fc3a28-a488-43b5-b98f-6ea9b3b77223","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bda3d866-c29f-4750-bc69-99792b129a32","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":383,"regions":"OESTE"}],"color":["#00ad9c"],"employees":[383],"fill_alpha":[0.8],"height":[383.0],"label":[{"employees":383,"regions":"OESTE"}],"line_alpha":[1.0],"line_color":["white"],"regions":["OESTE"],"width":[0.8],"x":["OESTE"],"y":[191.5]}},"id":"e21e96b7-5b60-4fe5-b984-926ac2bd1a2a","type":"ColumnDataSource"},{"attributes":{"axis_label":"Regions","formatter":{"id":"d3dfe37f-0c2d-4bbf-96e2-c82685a1b857","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"b77fe219-a37a-4059-869f-b8981fa5ed6f","subtype":"Chart","type":"Plot"},"ticker":{"id":"7239288e-0eea-44e9-9c50-d9463200f8a9","type":"CategoricalTicker"}},"id":"18dbbe84-8634-4ba3-a237-937d3d657ddd","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"8de82eb5-1382-4021-bf26-d02e0385c42a","type":"ColumnDataSource"},"glyph":{"id":"47a868a0-2af3-4dfe-9cd3- ...

# %%
from src.visualization.charts.places_by_region import PlacesByRegion

placesByReg = PlacesByRegion(health_units)
unitsByReg = placesByReg.plot('Health units by region')

output_notebook()
show(unitsByReg)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aff8c4d8-abcf-4d4b-a048-db6e80cdfea7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0a3363aa-93dc-46f2-a70a-eef9bef5d7b2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0a3363aa-93dc-46f2-a70a-eef9bef5d7b2").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0a3363aa-93dc-46f2-a70a-eef9bef5d7b2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0a3363aa-93dc-46f2-a70a-eef9bef5d7b2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f562acd2-21f7-4548-a5a6-bdd7bf9f815a":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c6b3ea4b-49f2-4db5-a768-d032cc5263be","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"NORTE I","units":11}],"color":["#df5320"],"fill_alpha":[0.8],"height":[11.0],"label":[{"regions":"NORTE I","units":11}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE I"],"units":[11],"width":[0.8],"x":["NORTE I"],"y":[5.5]}},"id":"3899483b-9d78-4539-b43d-6965b13e9a2d","type":"ColumnDataSource"},{"attributes":{},"id":"2bf20d82-6fd4-4039-a47d-c0fa467b2d3d","type":"ToolEvents"},{"attributes":{"below":[{"id":"9025b221-dfe0-4eaa-b0c1-a5df2f076bcb","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"bf40b33f-e15c-470a-a215-9cd353072bbf","type":"LinearAxis"}],"renderers":[{"id":"a4e5b4ef-bbc6-4d84-852b-9f76f8d1362a","type":"BoxAnnotation"},{"id":"17b79d3e-f4a9-449e-8ec5-64c57bc648c3","type":"GlyphRenderer"},{"id":"8cd501e7-f44c-48c0-a6ab-4d1518ec9abc","type":"GlyphRenderer"},{"id":"db474ad7-84f1-4731-9654-cb719796d190","type":"GlyphRenderer"},{"id":"41586c65-125c-4b45-829d-c25dcda18d1e","type":"GlyphRenderer"},{"id":"ab7f95a3-b8e4-45fe-b0fc-c2593888f3a2","type":"GlyphRenderer"},{"id":"9025b221-dfe0-4eaa-b0c1-a5df2f076bcb","type":"CategoricalAxis"},{"id":"bf40b33f-e15c-470a-a215-9cd353072bbf","type":"LinearAxis"},{"id":"7c8f7ca8-6096-4ea6-9409-1e20645804a4","type":"Grid"}],"title":{"id":"71acc155-ae0d-438d-b0d2-af5e61c3da00","type":"Title"},"tool_events":{"id":"2bf20d82-6fd4-4039-a47d-c0fa467b2d3d","type":"ToolEvents"},"toolbar":{"id":"95347799-a128-4552-b27e-3144c7090385","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"3e02b595-78f1-4890-b01a-505879d6a5bd","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"e97ff43a-3a3c-42ad-9094-e17379ed896a","type":"Range1d"}},"id":"2f8e94f5-522d-4074-a6e3-c52ebae5ed1e","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"81601567-2a3d-437c-8792-863727eae7fa","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"NORTE II","units":10}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[10.0],"label":[{"regions":"NORTE II","units":10}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE II"],"units":[10],"width":[0.8],"x":["NORTE II"],"y":[5.0]}},"id":"53e9a2bf-29f0-49d1-a938-678db8443130","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8610e049-5f8e-4f8d-a3a6-8da03a9a05f9","type":"ColumnDataSource"},"glyph":{"id":"de70d4f3-ab0d-4e7a-9f00-4f96a172f52c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"17b79d3e-f4a9-449e-8ec5-64c57bc648c3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dacdc214-305e-437f-b832-db8ab2ab07e9","type":"Rect"},{"attributes":{"data_source":{"id":"3899483b-9d78-4539-b43d-6965b13e9a2d","type":"ColumnDataSource"},"glyph":{"id":"81601567-2a3d-437c-8792-863727eae7fa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8cd501e7-f44c-48c0-a6ab-4d1518ec9abc","type":"GlyphRenderer"},{"attributes":{"axis_label":"Regions","formatter":{"id":"79 ...

# %% [markdown]
# ### Municipal Schools

# %% [markdown]
# In this section we look at the amount of teachers who work in the municipal schools and how those schools are distributed on the city.

# %%
from src.data.get_mun_schools import GetMunicipalSchools

# Data collection of municipal schools
schools = GetMunicipalSchools.get()

# %% [markdown]
# #### Geographic visualization

# %%
from src.visualization.map.mun_schools_map import MunicipalSchoolsMap

# Generates a map showing the localization of each unit
# The green ones are CMEIs and the blue ones, Esc Mul
ms_map = MunicipalSchoolsMap(schools)
ms_map.generateMap()
# Out:
# 100%|██████████| 146/146 [00:08<00:00, 19.00it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from src.visualization.heatmap.mun_schools_heatmap import MunicipalSchoolsHeatmap

# Generates a heat map of each school by its amount of teachers
ms_heatmap = MunicipalSchoolsHeatmap(schools)
ms_heatmap.generateMap()
# Out:
# 100%|██████████| 146/146 [00:00<00:00, 123386.74it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Charts

# %%
from bokeh.io import output_notebook, show

# %%
from src.visualization.charts.employees_by_region import EmployeesByRegion

employeesByReg = EmployeesByRegion(schools)
teachersByRegions = employeesByReg.plot('Teachers by local region')

output_notebook()
show(teachersByRegions)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ea796bc6-1faf-4f2e-8276-840701bfbc87">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e57c26eb-c730-491b-b769-b2e2d26ff947"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e57c26eb-c730-491b-b769-b2e2d26ff947").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e57c26eb-c730-491b-b769-b2e2d26ff947");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e57c26eb-c730-491b-b769-b2e2d26ff947' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"25dcab8a-5506-4639-bbc2-5cd5735310f2":{"roots":{"references":[{"attributes":{"plot":null,"text":"Teachers by local region"},"id":"fc443871-c7f3-4894-aada-0ed1b813e6be","type":"Title"},{"attributes":{},"id":"d62fdac6-2e9b-4bb0-8f2f-5cdbcc0e297f","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"066e4ef0-25bc-433e-b4fd-3e149557c850","subtype":"Chart","type":"Plot"},"ticker":{"id":"d62fdac6-2e9b-4bb0-8f2f-5cdbcc0e297f","type":"BasicTicker"}},"id":"d3e0f777-a78e-48f6-9121-8034151319f3","type":"Grid"},{"attributes":{"callback":null,"factors":["LESTE","NORTE","N\u00c3O DEFINIDO","OESTE","SUL"]},"id":"c0634673-9db4-4992-9a09-729b4f2699c1","type":"FactorRange"},{"attributes":{},"id":"55a31051-f4d4-4714-bdbb-089a6a3582c5","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2001aa10-fee5-4417-aa41-fb74a658f4c6","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":1960,"regions":"OESTE"}],"color":["#df5320"],"employees":[1960],"fill_alpha":[0.8],"height":[1960.0],"label":[{"employees":1960,"regions":"OESTE"}],"line_alpha":[1.0],"line_color":["white"],"regions":["OESTE"],"width":[0.8],"x":["OESTE"],"y":[980.0]}},"id":"7caf718e-6a29-48d0-b7ae-fceacd08dc4e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7caf718e-6a29-48d0-b7ae-fceacd08dc4e","type":"ColumnDataSource"},"glyph":{"id":"5753cf05-b757-44cb-9e89-710277173762","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8725b82d-a257-4bce-94b4-cee13dddaca7","type":"GlyphRenderer"},{"attributes":{"axis_label":"Mean( Employees )","formatter":{"id":"8f7f5f77-fcf8-4e40-b16b-eb74b5852db1","type":"BasicTickFormatter"},"plot":{"id":"066e4ef0-25bc-433e-b4fd-3e149557c850","subtype":"Chart","type":"Plot"},"ticker":{"id":"d62fdac6-2e9b-4bb0-8f2f-5cdbcc0e297f","type":"BasicTicker"}},"id":"f7c12def-8893-493a-b107-b478be767707","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":767,"regions":"SUL"}],"color":["#407ee7"],"employees":[767],"fill_alpha":[0.8],"height":[767.0],"label":[{"employees":767,"regions":"SUL"}],"line_alpha":[1.0],"line_color":["white"],"regions":["SUL"],"width":[0.8],"x":["SUL"],"y":[383.5]}},"id":"99c0bbd6-06cb-4a61-b116-e102d1ffac8a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5943caea-b56c-4bcc-b957-12e37ac474cc","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"14a761f4-336f-415f-bb4d-2fea587987b0","type":"Rect"},{"attributes":{"below":[{"id":"97a84725-ada3-42c6-9dc9-367e5934e72a","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"f7c12def-8893-493a-b107-b478be767707","type":"LinearAxis"}],"renderers":[{"id":"2f4d16d8-1d17-40e1-8ad8-6f42f4883224","type":"BoxAnnotation"},{"id":"90b6e721-096d-4557-963c-4e79c840a034","type":"GlyphRenderer"},{"id":"dd0aeb87-fa17-4105-9568-04ef3f0cff00","type":"GlyphRenderer"},{"id":"cfcf0ca6-1e4c-40d3-898d-2ef0494d6e11","type":"GlyphRenderer"},{"id":"8725b82d-a257-4bce-94b4-cee13dddaca7","type":"GlyphRenderer"},{"id":"af239479-10c7-4101-8984-6ad302b17dcf","type":"GlyphRenderer"},{"id":"97a84725-ada3-42c6-9dc9-367e5934e72a","type":"CategoricalAxis"}, ...

# %%
from src.visualization.charts.places_by_region import PlacesByRegion

placesByReg = PlacesByRegion(schools)
schoolsByReg = placesByReg.plot('Schools by region')

output_notebook()
show(schoolsByReg)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb3ff354-c319-4621-a494-4ee0d4fa0cca">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cc2fcda8-9801-4f41-968e-7a6343939d5e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cc2fcda8-9801-4f41-968e-7a6343939d5e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cc2fcda8-9801-4f41-968e-7a6343939d5e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cc2fcda8-9801-4f41-968e-7a6343939d5e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7a7b961e-86e0-4c72-9131-95920dff641e":{"roots":{"references":[{"attributes":{"plot":{"id":"0d3aa394-a473-42b0-be41-b29be45c6934","subtype":"Chart","type":"Plot"}},"id":"59af5f3f-858e-4815-bd2d-ec8153480c3b","type":"HelpTool"},{"attributes":{"data_source":{"id":"64fb6dac-741d-4116-a1b4-8bd0ca448fe8","type":"ColumnDataSource"},"glyph":{"id":"e6de5036-f0ea-452f-9a3e-e8f70effb854","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2d5adab8-307b-4ef4-83d4-69a5e3d31cc0","type":"GlyphRenderer"},{"attributes":{},"id":"6c0bacfa-8c8b-454f-91e0-4eadcd87af7a","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"LESTE","units":17}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[17.0],"label":[{"regions":"LESTE","units":17}],"line_alpha":[1.0],"line_color":["white"],"regions":["LESTE"],"units":[17],"width":[0.8],"x":["LESTE"],"y":[8.5]}},"id":"4b8ebedd-d70a-4274-9b5c-cb90c0241f43","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"de342333-241b-4729-88c8-e1297a9440de","type":"Rect"},{"attributes":{"plot":null,"text":"Schools by region"},"id":"5a4065de-819f-44d0-8ac8-8d88d4d44287","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1741d92d-ef90-4bad-a0c7-6408a0320640","type":"Rect"},{"attributes":{"plot":{"id":"0d3aa394-a473-42b0-be41-b29be45c6934","subtype":"Chart","type":"Plot"}},"id":"7d8e5911-0596-4337-bb75-ea45aa47f376","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"89a439c7-6ee2-4a8f-85f4-fd998d9cd2ac","type":"Rect"},{"attributes":{"callback":null,"end":57.75},"id":"fff74bbf-db27-428a-aec7-afa0edd43591","type":"Range1d"},{"attributes":{"data_source":{"id":"4b8ebedd-d70a-4274-9b5c-cb90c0241f43","type":"ColumnDataSource"},"glyph":{"id":"de342333-241b-4729-88c8-e1297a9440de","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6918baf3-a30a-4f0e-9d01-3eacc307fbfc","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"regions":"NORTE","units":55}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[55.0],"label":[{"regions":"NORTE","units":55}],"line_alpha":[1.0],"line_color":["white"],"regions":["NORTE"],"units":[55],"width":[0.8],"x":["NORTE"],"y":[27.5]}},"id":"59bc6fb0-27f7-4773-ba59-0ddf454f4bc6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a0e3f54e-07d4-4075-acd1-0deab86bc660","type":"Rect"},{"attributes":{},"id":"d02bccff-e5f2-4e91-979a-0aeb955dbcb5","type":"ToolEvents"},{"attributes":{"data_source":{"id":"59bc6fb0-27f7-4773-ba59-0ddf454f4bc6","type":"ColumnDataSource"},"glyph":{"id":"89a439c7-6ee2-4a8f-85f4-fd998d9cd2ac","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fa118565-9689-4cac-8be9-c19781bec04d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"char ...

# %%
from src.visualization.charts.teachers_education import TeachersEducationPlot

# Chart summarizing teachers education
teacEduc = TeachersEducationPlot(schools)
teacEducPlot = teacEduc.plot()

output_notebook()
show(teacEducPlot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="acd82887-7808-4c7a-bf42-b953c1e2996d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2da8cc42-a132-4de5-9f87-e46e994da13c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2da8cc42-a132-4de5-9f87-e46e994da13c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2da8cc42-a132-4de5-9f87-e46e994da13c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2da8cc42-a132-4de5-9f87-e46e994da13c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"149a4477-bc37-4540-b565-abd9e043373e":{"roots":{"references":[{"attributes":{"axis_label":null,"formatter":{"id":"3655ca9d-10ec-4d7e-a548-1e9718900390","type":"BasicTickFormatter"},"plot":{"id":"e63e7856-96e7-456d-ad3a-b44db6179cc7","subtype":"Chart","type":"Plot"},"ticker":{"id":"e68b3f4b-75f6-44a4-98a9-d821f1447b2e","type":"BasicTicker"},"visible":false},"id":"0d9493d3-2e80-432a-a72c-7e57977686de","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","education"],"data":{"centers":[1.125,1.125,1.125,1.125],"color":["#f22c40","#5ab738","#407ee7","#df5320"],"education":["Ensino Superior","Especializa\u00e7\u00e3o","Mestrado","Nenhum"],"end":[3.141592653589793,4.383617656171804,4.529738244710864,6.283185307179586],"inners":[0.0,0.0,0.0,0.0],"level":[0.0,0.0,0.0,0.0],"outers":[1.5,1.5,1.5,1.5],"start":[0.0,3.141592653589793,4.383617656171804,4.529738244710864],"values":[6278,2482,292,3504]}},"id":"22c8d216-1cbb-4558-9cde-6514e8af8346","type":"ColumnDataSource"},{"attributes":{"axis_label":null,"formatter":{"id":"f72aaa6f-66bc-4b78-a7a1-7d741a9c1221","type":"BasicTickFormatter"},"plot":{"id":"e63e7856-96e7-456d-ad3a-b44db6179cc7","subtype":"Chart","type":"Plot"},"ticker":{"id":"f268026e-0fc5-49f5-a861-ec972c772be8","type":"BasicTicker"},"visible":false},"id":"2a416cb9-cf3f-4118-aa89-2c945509dc67","type":"LinearAxis"},{"attributes":{"location":"top_left","plot":{"id":"e63e7856-96e7-456d-ad3a-b44db6179cc7","subtype":"Chart","type":"Plot"}},"id":"ae283339-fdb9-492a-a7a6-82a656843db3","type":"Legend"},{"attributes":{"callback":null,"column_names":["text","x","y","text_angle"],"data":{"text":["Ensino Superior","Especializa\u00e7\u00e3o","Mestrado","Nenhum"],"text_angle":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=","dtype":"float64","shape":[4]},"x":[6.888638245203862e-17,-0.9149509583275112,-0.28455005519064186,0.719632149253752],"y":[1.125,-0.6545912800026967,-1.088419159189603,-0.8647280322508492]}},"id":"32afb6d7-bca5-4500-9470-b9dee9b0fe09","type":"ColumnDataSource"},{"attributes":{},"id":"3655ca9d-10ec-4d7e-a548-1e9718900390","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"32afb6d7-bca5-4500-9470-b9dee9b0fe09","type":"ColumnDataSource"},"glyph":{"id":"cc0001ce-d5d4-4fbd-8e7e-0db5a9ae5c07","type":"Text"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1d172853-16b4-4ea3-ae8c-9d81677c89dc","type":"GlyphRenderer"},{"attributes":{},"id":"e68b3f4b-75f6-44a4-98a9-d821f1447b2e","type":"BasicTicker"},{"attributes":{"below":[{"id":"0d9493d3-2e80-432a-a72c-7e57977686de","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"2a416cb9-cf3f-4118-aa89-2c945509dc67","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"13ac4933-9b9b-4d58-8f6e-dcd90bcb647a","type":"BoxAnnotation"},{"id":"90442661-1367-48a8-8500-a7484098ca2c","type":"GlyphRenderer"},{"id":"1d172853-16b4-4ea3-ae8c-9d81677c89dc","type":"GlyphRenderer"},{"id":"ae283339-fdb9-492a-a7a6-82a656843db3","type":"Legend"},{"id":"0d9493d3-2e80-432a-a72c-7e57977686de","type":"LinearAxis"},{"id":"2a416cb9-cf3f-4118-aa89-2c945509dc67","type":"LinearAxis"}],"title":{"id":"c9b8a85a-8825-485e-bcb6-a955292e0f3c","type":"Title"},"tool_events":{"id":"51e60f93-b90a-4480-8a6f-caa1dbfe7768","type":"ToolEvents"},"toolbar":{"id":"264f2077-d75a-483a-b717-adf53cc3f2f3","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"740bff3b-c607-4633-ade1-2ef382ff5a19","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"413b6576-6ae5-4cc9-bb38-bc50d3001505","type":"Range1d"}},"id":"e63e7856-96e7-456d-ad3a-b44db6179cc7","subtype":"Chart","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9e7a4157-d19f-4a32-becb-6250791e3f50","type":"PanTool"},{"id":"4196dd8e-5693-4abc-bf55-b35ed260e826","type":"WheelZoomTool"},{"id":"5db64ed2-3f46-4654-a593-f7c93d42ff1b","ty ...

# %% [markdown]
# ### Municipal Schools vs. Health Units

# %% [markdown]
# This is a briefly summary of Schools and Health Units.

# %%
from bokeh.io import output_notebook, show
from bokeh.models.widgets import Panel, Tabs

# %%
from src.visualization.charts.places import PlacesPlot
from src.visualization.charts.employees import EmployeesPlot

placesPlot = PlacesPlot(health_units, schools)
placesFigure = placesPlot.plot()
tab1 = Panel(child = placesFigure, title = 'Places')

empPlot = EmployeesPlot(health_units, schools)
empFigure = empPlot.plot()
tab2 = Panel(child = empFigure, title = 'Employees')

output_notebook()
show(Tabs(tabs = [tab1, tab2]))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="790d2ce6-eaf1-4ca2-aff2-3baefde07bfb">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d0dd835e-d630-46b8-b64d-380aea2c0c07"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d0dd835e-d630-46b8-b64d-380aea2c0c07").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d0dd835e-d630-46b8-b64d-380aea2c0c07");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd0dd835e-d630-46b8-b64d-380aea2c0c07' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"88825bcb-2e93-43df-9e1f-062a3dc37cc2":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"fef29580-ccbd-4ec4-9ff1-1d3a7948fbcd","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bdfd945f-94e1-45f9-acf3-72d1aa870e72","type":"PanTool"},{"id":"eff55971-ad1f-4c2a-ad62-016331471a57","type":"WheelZoomTool"},{"id":"45a532ce-85d2-4499-9242-c6eece69446b","type":"BoxZoomTool"},{"id":"825e0963-da08-4f5a-a001-a3ce51518168","type":"SaveTool"},{"id":"f985f229-d780-49c6-9adb-9da19effa235","type":"ResetTool"},{"id":"ca2bbe6d-b25a-4128-a2ee-c6f4fe6db510","type":"HelpTool"},{"id":"636027ee-f410-4ff7-b97d-f90663e60523","type":"HoverTool"}]},"id":"bce6eb88-4c80-4fa3-9a28-179a5740b9e9","type":"Toolbar"},{"attributes":{"plot":{"id":"6bec807d-5a27-4aca-9097-bf3aebd24544","subtype":"Chart","type":"Plot"}},"id":"1641ae98-229b-4596-b966-b8c9a0841070","type":"HelpTool"},{"attributes":{"plot":null,"text":"Municipal Schools and Health Units (Total of employees)"},"id":"5fdad646-7c23-4b17-824b-3927b73b2a68","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d9837cc9-650e-48c4-b670-8c1db3717007","type":"BoxAnnotation"},{"attributes":{"axis_label":"Mean( Employees )","formatter":{"id":"45ac8c11-7236-45ee-8a5e-b2875a87ee06","type":"BasicTickFormatter"},"plot":{"id":"202c8d6b-6f9d-4db8-b4e1-4ccc5464d79c","subtype":"Chart","type":"Plot"},"ticker":{"id":"a6d5bbbb-c0ef-4c90-a64f-654e610d2e21","type":"BasicTicker"}},"id":"74806cbe-0747-4a39-8eb7-850ec7014891","type":"LinearAxis"},{"attributes":{"plot":{"id":"202c8d6b-6f9d-4db8-b4e1-4ccc5464d79c","subtype":"Chart","type":"Plot"}},"id":"bdfd945f-94e1-45f9-acf3-72d1aa870e72","type":"PanTool"},{"attributes":{"plot":{"id":"202c8d6b-6f9d-4db8-b4e1-4ccc5464d79c","subtype":"Chart","type":"Plot"}},"id":"eff55971-ad1f-4c2a-ad62-016331471a57","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"d9837cc9-650e-48c4-b670-8c1db3717007","type":"BoxAnnotation"},"plot":{"id":"202c8d6b-6f9d-4db8-b4e1-4ccc5464d79c","subtype":"Chart","type":"Plot"}},"id":"45a532ce-85d2-4499-9242-c6eece69446b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"202c8d6b-6f9d-4db8-b4e1-4ccc5464d79c","subtype":"Chart","type":"Plot"}},"id":"825e0963-da08-4f5a-a001-a3ce51518168","type":"SaveTool"},{"attributes":{"plot":{"id":"202c8d6b-6f9d-4db8-b4e1-4ccc5464d79c","subtype":"Chart","type":"Plot"}},"id":"f985f229-d780-49c6-9adb-9da19effa235","type":"ResetTool"},{"attributes":{"plot":{"id":"202c8d6b-6f9d-4db8-b4e1-4ccc5464d79c","subtype":"Chart","type":"Plot"}},"id":"ca2bbe6d-b25a-4128-a2ee-c6f4fe6db510","type":"HelpTool"},{"attributes":{"axis_label":"Mean( Units )","formatter":{"id":"57d28cf1-6f7b-4044-89e5-d8beb3cebe29","type":"BasicTickFormatter"},"plot":{"id":"6bec807d-5a27-4aca-9097-bf3aebd24544","subtype":"Chart","type":"Plot"},"ticker":{"id":"21ad70aa-0360-4ffd-a3a5-8855e3d75717","type":"BasicTicker"}},"id":"d7f5fe56-f63a-4e70-92bc-a91369c239c1","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"employees":1227,"places":"Health units"}],"color":["#f22c40"],"employees":[1227],"fill_alpha":[0.8],"height":[1227.0],"label":[{"employees":1227,"places":"Health units"}],"line_alpha":[1.0],"line_color":["white"],"places":["Health units"],"width":[0.8],"x":["Health  ...

# %%
### REQUIREMENTS

### Libraries necessary to run this IPython Notebook

# !pip install folium
# !pip install geocoder
# !pip install tqdm

# %% [markdown]
# **Rubem Kalebe**
